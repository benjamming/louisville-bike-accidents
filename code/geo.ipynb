# %%
import pandas as pd
import os
import operator
import geopandas

os.chdir("/Users/bencampbell/code_louisville/capstone/louisville-bike-accidents/")

DATA = "data/clean/bike_accidents.csv"
assert os.path.exists(DATA)

df = pd.read_csv(DATA)
#df

# %%
points = geopandas.GeoSeries(geopandas.points_from_xy(df.longitude, df.latitude))
points.plot()
# Out:
# <Axes: >

# %%
import matplotlib
